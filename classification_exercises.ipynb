# %%
import pandas as pd
import numpy as np
import os
from env import host, username, password, get_db_url
from pydataset import data
from sklearn.model_selection import train_test_split

# %%
### ACQUIRE ###

# %%
df_iris = data('iris')
df_iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %%
# print the first 3 rows

# %%
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
# print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 5)

# %%
# print the column names and print the data type of each column

# %%
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
# print the summary statistics for each of the numeric variables

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Read the data from this google sheet into a dataframe, df_google

# %%
# Print the first 3 rows

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_google = pd.read_csv(csv_export_url)
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# print the number of rows and columns

# %%
df_google.shape
# Out:
# (891, 12)

# %%
# print the column names

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# print the data type of each column and print the summary statistics for each of the numeric variables

# %%
df_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# print the unique values for each of your categorical variables

# %%
df_google.nunique
# Out:
# <bound method DataFrame.nunique of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Read the downloaded file into a dataframe named df_excel

# %%
df_excel = pd.read_clipboard()
df_excel
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_excel = pd.read_clipboard()
#       2 df_excel
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/pandas/io/clipboards.py:79, in read_clipboard(sep, dtype_backend, **kwargs)
#      73     pass
#      75 # Excel copies into clipboard with \t separation
#      76 # inspect no more then the 10 first lines, if they
#      77 # all contain an equal number (>0) of tabs, infer
#      78 # that this came from excel and set 'sep' accordingly
# ---> 79 lines = text[:10000].split("\n")[:-1][:10]
#      81 # Need to remove leading white space, since read_csv
#      82 # accepts:
#      83 #    a  b
#      84 # 0  1  2
#      85 # 1  3  4
#      87 counts = {x.lstrip(" ").count("\t") for x in lines}
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = df_excel.head(101)
df_excel_sample

# %%
# print the number of rows of your original dataframe

# %%
df_excel.shape

# %%
# print the first 5 column names

# %%
df_excel.columns[:5]

# %%
# print the column names that have a data type of object

# %%
df_excel.select_dtypes(include='object')

# %%
# Make a new python module, acquire.py to hold the following data aquisition functions

# %%
### PREPARE ###

# %%
# Use the function defined in acquire.py to load the iris data.

# %%
import acquire

# %%
df = acquire.get_iris_data()
df
# Out:
#      species_id species_name  sepal_length  sepal_width  petal_length  \
# 0             1       setosa           5.1          3.5           1.4
# 1             1       setosa           4.9          3.0           1.4
# 2             1       setosa           4.7          3.2           1.3
# 3             1       setosa           4.6          3.1           1.5
# 4             1       setosa           5.0          3.6           1.4
# 5             1       setosa           5.4          3.9           1.7
# 6             1       setosa           4.6          3.4           1.4
# 7             1       setosa           5.0          3.4           1.5
# 8             1       setosa           4.4          2.9           1.4
# 9             1       setosa           4.9          3.1           1.5
# 10            1       setosa           5.4          3.7           1.5
# 11            1       setosa           4.8          3.4           1.6
# ...

# %%
# Drop the species_id and measurement_id columns

# %%
df = df.drop(columns='species_id')
df
# Out:
#     species_name  sepal_length  sepal_width  petal_length  petal_width
# 0         setosa           5.1          3.5           1.4          0.2
# 1         setosa           4.9          3.0           1.4          0.2
# 2         setosa           4.7          3.2           1.3          0.2
# 3         setosa           4.6          3.1           1.5          0.2
# 4         setosa           5.0          3.6           1.4          0.2
# 5         setosa           5.4          3.9           1.7          0.4
# 6         setosa           4.6          3.4           1.4          0.3
# 7         setosa           5.0          3.4           1.5          0.2
# 8         setosa           4.4          2.9           1.4          0.2
# 9         setosa           4.9          3.1           1.5          0.1
# 10        setosa           5.4          3.7           1.5          0.2
# 11        setosa           4.8          3.4           1.6          0.2
# ...

# %%
# Rename the species_name column to just species

# %%
df = df.rename(columns = {'species_name' : 'species'})
df
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %%
# Create dummy variables of the species name and concatenate onto the iris dataframe

# %%
df_dummy = pd.get_dummies(df.species, drop_first = True)
df_dummy
# Out:
#      versicolor  virginica
# 0         False      False
# 1         False      False
# 2         False      False
# 3         False      False
# 4         False      False
# 5         False      False
# 6         False      False
# 7         False      False
# 8         False      False
# 9         False      False
# 10        False      False
# 11        False      False
# 12        False      False
# 13        False      False
# 14        False      False
# 15        False      False
# 16        False      False
# 17        False      False
# 18        False      False
# 19        False      False
# 20        False      False
# 21        False      False
# 22        False      False
# 23        False      False
# 24        False      False
# 25        False      False
# 26        False      False
# 27        False      False
# 28        False      False
# 29        False      False
# 30        False      False
# 31        False      False
# 32        False      False
# ...

# %%
df = pd.concat([df, df_dummy], axis=1)
df
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width  \
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %%
# Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied

# %%
def prep_iris(df):
    df = df.drop(columns='species')
    df = df.rename(columns = {'species_name' : 'species'})
    df = pd.concat([df, df_dummy], axis=1)
    return df

# %%
prep_iris(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  versicolor  \
# 0             5.1          3.5           1.4          0.2       False
# 1             4.9          3.0           1.4          0.2       False
# 2             4.7          3.2           1.3          0.2       False
# 3             4.6          3.1           1.5          0.2       False
# 4             5.0          3.6           1.4          0.2       False
# 5             5.4          3.9           1.7          0.4       False
# 6             4.6          3.4           1.4          0.3       False
# 7             5.0          3.4           1.5          0.2       False
# 8             4.4          2.9           1.4          0.2       False
# 9             4.9          3.1           1.5          0.1       False
# 10            5.4          3.7           1.5          0.2       False
# 11            4.8          3.4           1.6          0.2       False
# ...

# %%
# Use the function defined in acquire.py to load the Titanic data

# %%
df1 = acquire.get_titanic_data()
df1
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class deck  embark_town  alone
# ...

# %%
# Drop any unnecessary, unhelpful, or duplicated columns.

# %%
df1 = df1.drop(columns = {'passenger_id' ,'pclass' , 'sibsp', 'parch' , 'deck', 'embarked'})
df1
# Out:
#      survived     sex   age     fare   class  embark_town  alone
# 0           0    male  22.0   7.2500   Third  Southampton      0
# 1           1  female  38.0  71.2833   First    Cherbourg      0
# 2           1  female  26.0   7.9250   Third  Southampton      1
# 3           1  female  35.0  53.1000   First  Southampton      0
# 4           0    male  35.0   8.0500   Third  Southampton      1
# ..        ...     ...   ...      ...     ...          ...    ...
# 886         0    male  27.0  13.0000  Second  Southampton      1
# 887         1  female  19.0  30.0000   First  Southampton      1
# 888         0  female   NaN  23.4500   Third  Southampton      0
# 889         1    male  26.0  30.0000   First    Cherbourg      1
# 890         0    male  32.0   7.7500   Third   Queenstown      1
#
# [891 rows x 7 columns]

# %%
# Encode the categorical columns

# %%
df1_dummy = pd.get_dummies(df1.alone, drop_first = True)
df1_dummy
# Out:
#          1
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# ..     ...
# 886   True
# 887   True
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
df1 = pd.concat([df1, df1_dummy], axis=1)
df1
# Out:
#      survived     sex   age     fare   class  embark_town  alone      1
# 0           0    male  22.0   7.2500   Third  Southampton      0  False
# 1           1  female  38.0  71.2833   First    Cherbourg      0  False
# 2           1  female  26.0   7.9250   Third  Southampton      1   True
# 3           1  female  35.0  53.1000   First  Southampton      0  False
# 4           0    male  35.0   8.0500   Third  Southampton      1   True
# ..        ...     ...   ...      ...     ...          ...    ...    ...
# 886         0    male  27.0  13.0000  Second  Southampton      1   True
# 887         1  female  19.0  30.0000   First  Southampton      1   True
# 888         0  female   NaN  23.4500   Third  Southampton      0  False
# 889         1    male  26.0  30.0000   First    Cherbourg      1   True
# 890         0    male  32.0   7.7500   Third   Queenstown      1   True
#
# [891 rows x 8 columns]

# %%
# Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied

# %%
def prep_titanic(df1):
    df1_dummy = pd.get_dummies(df1.alone, drop_first = True)
    df1 = pd.concat([df1, df1_dummy], axis=1)
    return df1

# %%
prep_titanic(df1)

# %%
# Use the function defined in acquire.py to load the Telco data.

# %%
df2 = acquire.get_telco_data()

# %%
df2
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   2                         1                 2  0002-ORFBO
# 1                   2                         1                 1  0003-MKNFE
# 2                   1                         2                 1  0004-TLHLJ
# 3                   1                         2                 1  0011-IGKFF
# 4                   2                         2                 1  0013-EXCHZ
# ...               ...                       ...               ...         ...
# 7038                2                         1                 2  9987-LUTYD
# 7039                1                         2                 1  9992-RRAMN
# 7040                2                         1                 1  9992-UJOEL
# 7041                2                         1                 3  9993-LHIEB
# 7042                1                         1                 3  9995-HOTOH
#
# ...

# %%
# Drop any unnecessary, unhelpful, or duplicated columns

# %%
df2 = df2.drop(columns = {'payment_type_id' ,'multiple_lines', 'online_backup', 'online_security','device_protection','internet_service_type_id' , 'contract_type_id', 'senior_citizen' , 'partner', 'dependents','paperless_billing'})
df2
# Out:
#      customer_id  gender  tenure phone_service tech_support streaming_tv  \
# 0     0002-ORFBO  Female       9           Yes          Yes          Yes
# 1     0003-MKNFE    Male       9           Yes           No           No
# 2     0004-TLHLJ    Male       4           Yes           No           No
# 3     0011-IGKFF    Male      13           Yes           No          Yes
# 4     0013-EXCHZ  Female       3           Yes          Yes          Yes
# ...          ...     ...     ...           ...          ...          ...
# 7038  9987-LUTYD  Female      13           Yes          Yes           No
# 7039  9992-RRAMN    Male      22           Yes           No           No
# 7040  9992-UJOEL    Male       2           Yes           No           No
# 7041  9993-LHIEB    Male      67           Yes          Yes           No
# 7042  9995-HOTOH    Male      63            No           No          Yes
#
#      streaming_movies  monthly_charges total_charges churn   contract_type  \
# ...

# %%
# Encode the categorical columns

# %%
df2_dummy = pd.get_dummies(df2.tenure, drop_first = True)
df2 = pd.concat([df2, df2_dummy], axis=1)
df2
# Out:
#      customer_id  gender  tenure phone_service tech_support streaming_tv  \
# 0     0002-ORFBO  Female       9           Yes          Yes          Yes
# 1     0003-MKNFE    Male       9           Yes           No           No
# 2     0004-TLHLJ    Male       4           Yes           No           No
# 3     0011-IGKFF    Male      13           Yes           No          Yes
# 4     0013-EXCHZ  Female       3           Yes          Yes          Yes
# ...          ...     ...     ...           ...          ...          ...
# 7038  9987-LUTYD  Female      13           Yes          Yes           No
# 7039  9992-RRAMN    Male      22           Yes           No           No
# 7040  9992-UJOEL    Male       2           Yes           No           No
# 7041  9993-LHIEB    Male      67           Yes          Yes           No
# 7042  9995-HOTOH    Male      63            No           No          Yes
#
#      streaming_movies  monthly_charges total_charges churn  ...     63     64  \
# ...

# %%
# Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied

# %%
def prep_telco(df2):
    df2_dummy = pd.get_dummies(df2.tenure, drop_first = True)
    df2 = pd.concat([df2, df2_dummy], axis=1)
    return df

# %%
prep_telco(df2)
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width  \
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %%
# Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %%
import prepare

# %%
target_val = 'species'

# %%
df_train, df_validate, df_test = prepare.split(df, target_val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_train, df_validate, df_test = prepare.split(df, target_val)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
print(f'Prepared df: {df.shape}')
# Out:
# Prepared df: (150, 7)

# %%
### EXPLORATORY ANALYSIS ###
